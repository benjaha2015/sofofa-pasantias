# %%
import pandas as pd 
ds = pd.read_csv("SUBa.csv")
ds.head(10)
# Out:
#         Región    Provincia         Comuna  Seleccionados  Pagados  \
# 0     Tarapacá      Iquique        Iquique            593      203
# 1     Tarapacá      Iquique  Alto Hospicio            291      104
# 2     Tarapacá    Tamarugal   Pozo Almonte             31       10
# 3     Tarapacá    Tamarugal         Camiña              3        0
# 4     Tarapacá    Tamarugal       Colchane              1        1
# 5     Tarapacá    Tamarugal          Huara              4        0
# 6     Tarapacá    Tamarugal           Pica             10        5
# 7  Antofagasta  Antofagasta    Antofagasta            439      185
# 8  Antofagasta  Antofagasta     Mejillones              5        4
# 9  Antofagasta  Antofagasta   Sierra Gorda              1        0
#
#    Código Único Territorial            Programa                         Capa
# 0                      1101  Arriendo_2014_2019  Subsidio Arriendo 2014-2019
# ...

# %%
def filtro_region(df, region):
    df_filtrada = df(region, 1)
    pass

# %%
df = pd.read_csv('bono.csv')
df.head()
# Out:
#    _id Region  Cod.Comuna   Glosa.Comuna  No en PBS  Mto.en PBS  No sin PBS  \
# 0    1   15.0     15101.0          ARICA     1711.0   16865.228       175.0
# 1    2   15.0     15102.0      CAMARONES        7.0      85.364         0.0
# 2    3   15.0     15201.0          PUTRE       18.0     299.765         1.0
# 3    4   15.0     15202.0  GENERAL LAGOS       10.0     174.932         0.0
# 4    5    1.0      1101.0        IQUIQUE     1245.0   11184.990       117.0
#
#    Mto.sin PBS  No en APS Internas  Mto.en APS Internas  Total No  \
# 0     1735.217                75.0              879.887      1961
# 1        0.000                 0.0                0.000         7
# 2       15.782                 0.0                0.000        19
# 3        0.000                 0.0                0.000        10
# 4     1702.094                76.0              941.906      1438
#
#    Total Mto. m$
# 0      19480.332
# 1         85.364
# 2        315.547
# 3        174.932
# 4      13828.990

# %%
dc = pd.read_csv("leype.csv")
dc
# Out:
#      Año        Mes Moneda  Subtítulo                       Nombre Subtítulo  \
# 0   2022  Noviembre  PESOS          8              OTROS INGRESOS CORRIENTES
# 1   2022  Noviembre  PESOS         15                  SALDO INICIAL DE CAJA
# 2   2022  Noviembre  PESOS         21                     GASTOS EN PERSONAL
# 3   2022  Noviembre  PESOS         22          BIENES Y SERVICIOS DE CONSUMO
# 4   2022  Noviembre  PESOS         24              TRANSFERENCIAS CORRIENTES
# 5   2022  Noviembre  PESOS         29  ADQUISICIÓN DE ACTIVOS NO FINANCIEROS
# 6   2022  Noviembre  PESOS         31               INICIATIVAS DE INVERSIÓN
# 7   2022  Noviembre  PESOS         32                              PRÉSTAMOS
# 8   2022  Noviembre  PESOS         33              TRANSFERENCIAS DE CAPITAL
# 9   2022  Noviembre  PESOS         34                   SERVICIO DE LA DEUDA
# 10  2022  Noviembre  PESOS         35                    SALDO FINAL DE CAJA
#
# ...
